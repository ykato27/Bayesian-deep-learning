# %% [markdown]
# <a href="https://colab.research.google.com/github/ykato27/Time-Series-Deep-Learning/blob/main/LSTM_pytorch_wave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Simple LSTM model in PyTorch for predicting noisy sine wave data

# %%
import torch
import torch.nn as nn
from torch.optim import SGD
import math
import numpy as np

# %%
class Predictor(nn.Module):
    def __init__(self, inputDim, hiddenDim, outputDim):
        super(Predictor, self).__init__()

        self.rnn = nn.LSTM(input_size = inputDim,
                            hidden_size = hiddenDim,
                            batch_first = True)
        self.output_layer = nn.Linear(hiddenDim, outputDim)
    
    def forward(self, inputs, hidden0=None):
        output, (hidden, cell) = self.rnn(inputs, hidden0)
        output = self.output_layer(output[:, -1, :])

        return output

# %%
def mkDataSet(data_size, data_length=50, freq=60., noise=0.01):
    """
    params\n
    data_size : データセットサイズ\n
    data_length : 各データの時系列長\n
    freq : 周波数\n
    noise : ノイズの振幅\n
    returns\n
    train_x : トレーニングデータ（t=1,2,...,size-1の値)\n
    train_t : トレーニングデータのラベル（t=sizeの値）\n
    """
    train_x = []
    train_t = []

    for offset in range(data_size):
        train_x.append([[math.sin(2 * math.pi * (offset + i) / freq) + np.random.normal(loc=0.0, scale=noise)] for i in range(data_length)])
        train_t.append([math.sin(2 * math.pi * (offset + data_length) / freq)])

    return train_x, train_t

# %%
def mkRandomBatch(train_x, train_t, batch_size=10):
    """
    train_x, train_tを受け取ってbatch_x, batch_tを返す。
    """
    batch_x = []
    batch_t = []

    for i in range(batch_size):
#        idx = np.random.randint(0, len(train_x) - 1)
        idx= i
        batch_x.append(train_x[idx])
        batch_t.append(train_t[idx])
    
    return torch.tensor(batch_x), torch.tensor(batch_t)

# %%
training_size = 10000
test_size = 1000
epochs_num = 300
hidden_size = 5
batch_size = 100

train_x, train_t = mkDataSet(training_size)
test_x, test_t = mkDataSet(test_size)

model = Predictor(1, hidden_size, 1)
criterion = nn.MSELoss()
optimizer = SGD(model.parameters(), lr=0.01)

for epoch in range(epochs_num):
        # training
        running_loss = 0.0
        training_accuracy = 0.0
        for i in range(int(training_size / batch_size)):
            optimizer.zero_grad()


            data, label = mkRandomBatch(train_x, train_t, batch_size)

            output = model(data)

            loss = criterion(output, label)
            loss.backward()
            optimizer.step()

            running_loss += loss.data
            training_accuracy += np.sum(np.abs((output.data - label.data).numpy()) < 0.1)

        #test
        test_accuracy = 0.0
        for i in range(int(test_size / batch_size)):
            offset = i * batch_size
            data, label = torch.tensor(test_x[offset:offset+batch_size]), torch.tensor(test_t[offset:offset+batch_size])
            output = model(data, None)

            test_accuracy += np.sum(np.abs((output.data - label.data).numpy()) < 0.1)
        
        training_accuracy /= training_size
        test_accuracy /= test_size

        print('%d loss: %.3f, training_accuracy: %.5f, test_accuracy: %.5f' % (
            epoch + 1, running_loss, training_accuracy, test_accuracy))
# Out:
# 1 loss: 50.028, training_accuracy: 0.06570, test_accuracy: 0.06800
# 2 loss: 32.689, training_accuracy: 0.10000, test_accuracy: 0.09100
# 3 loss: 21.386, training_accuracy: 0.11200, test_accuracy: 0.12000
# 4 loss: 11.634, training_accuracy: 0.14830, test_accuracy: 0.13100
# 5 loss: 6.205, training_accuracy: 0.14770, test_accuracy: 0.11900
# 6 loss: 4.258, training_accuracy: 0.15200, test_accuracy: 0.13600
# 7 loss: 3.643, training_accuracy: 0.16630, test_accuracy: 0.13500
# 8 loss: 3.363, training_accuracy: 0.17450, test_accuracy: 0.16500
# 9 loss: 3.166, training_accuracy: 0.21340, test_accuracy: 0.19900
# 10 loss: 3.000, training_accuracy: 0.25480, test_accuracy: 0.23000
# 11 loss: 2.854, training_accuracy: 0.26650, test_accuracy: 0.23400
# 12 loss: 2.723, training_accuracy: 0.28000, test_accuracy: 0.23800
# 13 loss: 2.605, training_accuracy: 0.28000, test_accuracy: 0.24200
# 14 loss: 2.497, training_accuracy: 0.28840, test_accuracy: 0.24300
# 15 loss: 2.398, training_accuracy: 0.29800, test_accuracy: 0.25700
# 16 loss: 2.307, training_accuracy: 0.31070, test_accuracy: 0.27700
# 17 loss: 2.222, training_accuracy: 0.32310, test_accuracy: 0.28300
# 18 loss: 2.144, training_accuracy: 0.33510, test_accuracy: 0.28600
# 19 loss: 2.070, training_accuracy: 0.33000, test_accuracy: 0.29300
# 20 loss: 2.002, training_accuracy: 0.33070, test_accuracy: 0.29800
# 21 loss: 1.937, training_accuracy: 0.34620, test_accuracy: 0.30400
# 22 loss: 1.876, training_accuracy: 0.37060, test_accuracy: 0.31300
# 23 loss: 1.819, training_accuracy: 0.39690, test_accuracy: 0.33200
# 24 loss: 1.764, training_accuracy: 0.40000, test_accuracy: 0.34500
# 25 loss: 1.712, training_accuracy: 0.40000, test_accuracy: 0.35300
# 26 loss: 1.663, training_accuracy: 0.40000, test_accuracy: 0.35800
# 27 loss: 1.616, training_accuracy: 0.41190, test_accuracy: 0.36600
# 28 loss: 1.571, training_accuracy: 0.44120, test_accuracy: 0.37500
# 29 loss: 1.527, training_accuracy: 0.45930, test_accuracy: 0.38800
# 30 loss: 1.485, training_accuracy: 0.47000, test_accuracy: 0.40000
# 31 loss: 1.445, training_accuracy: 0.47000, test_accuracy: 0.41300
# 32 loss: 1.406, training_accuracy: 0.47400, test_accuracy: 0.42800
# 33 loss: 1.369, training_accuracy: 0.48640, test_accuracy: 0.43800
# 34 loss: 1.332, training_accuracy: 0.50770, test_accuracy: 0.45300
# 35 loss: 1.297, training_accuracy: 0.52000, test_accuracy: 0.46000
# 36 loss: 1.262, training_accuracy: 0.52560, test_accuracy: 0.46700
# 37 loss: 1.228, training_accuracy: 0.53000, test_accuracy: 0.47200
# 38 loss: 1.195, training_accuracy: 0.53000, test_accuracy: 0.47700
# 39 loss: 1.163, training_accuracy: 0.53000, test_accuracy: 0.48400
# 40 loss: 1.131, training_accuracy: 0.53000, test_accuracy: 0.49200
# 41 loss: 1.100, training_accuracy: 0.53210, test_accuracy: 0.50500
# 42 loss: 1.070, training_accuracy: 0.54740, test_accuracy: 0.51500
# 43 loss: 1.040, training_accuracy: 0.55140, test_accuracy: 0.52200
# 44 loss: 1.010, training_accuracy: 0.56640, test_accuracy: 0.53300
# 45 loss: 0.981, training_accuracy: 0.58250, test_accuracy: 0.54900
# 46 loss: 0.952, training_accuracy: 0.59920, test_accuracy: 0.56500
# 47 loss: 0.924, training_accuracy: 0.61920, test_accuracy: 0.58000
# 48 loss: 0.895, training_accuracy: 0.63000, test_accuracy: 0.60300
# 49 loss: 0.868, training_accuracy: 0.65310, test_accuracy: 0.61600
# 50 loss: 0.840, training_accuracy: 0.67000, test_accuracy: 0.63900
# 224 loss: 0.049, training_accuracy: 1.00000, test_accuracy: 1.00000
# 225 loss: 0.048, training_accuracy: 1.00000, test_accuracy: 1.00000
# 226 loss: 0.048, training_accuracy: 1.00000, test_accuracy: 1.00000
# 227 loss: 0.048, training_accuracy: 1.00000, test_accuracy: 1.00000
# 228 loss: 0.048, training_accuracy: 1.00000, test_accuracy: 1.00000
# 229 loss: 0.048, training_accuracy: 1.00000, test_accuracy: 1.00000
# 230 loss: 0.048, training_accuracy: 1.00000, test_accuracy: 1.00000
# 231 loss: 0.047, training_accuracy: 1.00000, test_accuracy: 1.00000
# 232 loss: 0.047, training_accuracy: 1.00000, test_accuracy: 1.00000
# 233 loss: 0.047, training_accuracy: 1.00000, test_accuracy: 1.00000
# 234 loss: 0.047, training_accuracy: 1.00000, test_accuracy: 1.00000
# 235 loss: 0.047, training_accuracy: 1.00000, test_accuracy: 1.00000
# 236 loss: 0.046, training_accuracy: 1.00000, test_accuracy: 1.00000
# 237 loss: 0.046, training_accuracy: 1.00000, test_accuracy: 1.00000
# 238 loss: 0.046, training_accuracy: 1.00000, test_accuracy: 1.00000
# 239 loss: 0.046, training_accuracy: 1.00000, test_accuracy: 1.00000
# 240 loss: 0.046, training_accuracy: 1.00000, test_accuracy: 1.00000
# 241 loss: 0.046, training_accuracy: 1.00000, test_accuracy: 1.00000
# 242 loss: 0.045, training_accuracy: 1.00000, test_accuracy: 1.00000
# 243 loss: 0.045, training_accuracy: 1.00000, test_accuracy: 1.00000
# 244 loss: 0.045, training_accuracy: 1.00000, test_accuracy: 1.00000
# 245 loss: 0.045, training_accuracy: 1.00000, test_accuracy: 1.00000
# 246 loss: 0.045, training_accuracy: 1.00000, test_accuracy: 1.00000
# 247 loss: 0.045, training_accuracy: 1.00000, test_accuracy: 1.00000
# 248 loss: 0.044, training_accuracy: 1.00000, test_accuracy: 1.00000
# 249 loss: 0.044, training_accuracy: 1.00000, test_accuracy: 1.00000
# 250 loss: 0.044, training_accuracy: 1.00000, test_accuracy: 1.00000
# 251 loss: 0.044, training_accuracy: 1.00000, test_accuracy: 1.00000
# 252 loss: 0.044, training_accuracy: 1.00000, test_accuracy: 1.00000
# 253 loss: 0.044, training_accuracy: 1.00000, test_accuracy: 1.00000
# 254 loss: 0.044, training_accuracy: 1.00000, test_accuracy: 1.00000
# 255 loss: 0.043, training_accuracy: 1.00000, test_accuracy: 1.00000
# 256 loss: 0.043, training_accuracy: 1.00000, test_accuracy: 1.00000
# 257 loss: 0.043, training_accuracy: 1.00000, test_accuracy: 1.00000
# 258 loss: 0.043, training_accuracy: 1.00000, test_accuracy: 1.00000
# 259 loss: 0.043, training_accuracy: 1.00000, test_accuracy: 1.00000
# 260 loss: 0.043, training_accuracy: 1.00000, test_accuracy: 1.00000
# 261 loss: 0.043, training_accuracy: 1.00000, test_accuracy: 1.00000
# 262 loss: 0.042, training_accuracy: 1.00000, test_accuracy: 1.00000
# 263 loss: 0.042, training_accuracy: 1.00000, test_accuracy: 1.00000
# 264 loss: 0.042, training_accuracy: 1.00000, test_accuracy: 1.00000
# 265 loss: 0.042, training_accuracy: 1.00000, test_accuracy: 1.00000
# 266 loss: 0.042, training_accuracy: 1.00000, test_accuracy: 1.00000
# 267 loss: 0.042, training_accuracy: 1.00000, test_accuracy: 1.00000
# 268 loss: 0.042, training_accuracy: 1.00000, test_accuracy: 1.00000
# 269 loss: 0.042, training_accuracy: 1.00000, test_accuracy: 1.00000
# 270 loss: 0.041, training_accuracy: 1.00000, test_accuracy: 1.00000
# 271 loss: 0.041, training_accuracy: 1.00000, test_accuracy: 1.00000
# 272 loss: 0.041, training_accuracy: 1.00000, test_accuracy: 1.00000
# 273 loss: 0.041, training_accuracy: 1.00000, test_accuracy: 1.00000
# 274 loss: 0.041, training_accuracy: 1.00000, test_accuracy: 1.00000
# 275 loss: 0.041, training_accuracy: 1.00000, test_accuracy: 1.00000
# 276 loss: 0.041, training_accuracy: 1.00000, test_accuracy: 1.00000
# 277 loss: 0.041, training_accuracy: 1.00000, test_accuracy: 1.00000
# 278 loss: 0.040, training_accuracy: 1.00000, test_accuracy: 1.00000
# 279 loss: 0.040, training_accuracy: 1.00000, test_accuracy: 1.00000
# 280 loss: 0.040, training_accuracy: 1.00000, test_accuracy: 1.00000
# 281 loss: 0.040, training_accuracy: 1.00000, test_accuracy: 1.00000
# 282 loss: 0.040, training_accuracy: 1.00000, test_accuracy: 1.00000
# 283 loss: 0.040, training_accuracy: 1.00000, test_accuracy: 1.00000
# 284 loss: 0.040, training_accuracy: 1.00000, test_accuracy: 1.00000
# 285 loss: 0.040, training_accuracy: 1.00000, test_accuracy: 1.00000
# 286 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 287 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 288 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 289 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 290 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 291 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 292 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 293 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 294 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 295 loss: 0.039, training_accuracy: 1.00000, test_accuracy: 1.00000
# 296 loss: 0.038, training_accuracy: 1.00000, test_accuracy: 1.00000
# 297 loss: 0.038, training_accuracy: 1.00000, test_accuracy: 1.00000
# 298 loss: 0.038, training_accuracy: 1.00000, test_accuracy: 1.00000
# 299 loss: 0.038, training_accuracy: 1.00000, test_accuracy: 1.00000
# 300 loss: 0.038, training_accuracy: 1.00000, test_accuracy: 1.00000

# %%
import matplotlib.pyplot as plt

data, label = mkRandomBatch(test_x, test_t, batch_size)
output=model(data)

plt.figure()
plt.plot(output.data, color="r", label="predict_data")
plt.plot(label.data[:70], color="b", label="row_data")
plt.legend()
plt.show()
