# %% [markdown]
# ## Interpretable forecasting with N-Beats

# %%
# %load_ext lab_black

# %%
import os
import warnings

warnings.filterwarnings("ignore")

# %%
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping
import torch

from pytorch_forecasting import Baseline, NBeats, TimeSeriesDataSet
from pytorch_forecasting.data import NaNLabelEncoder
from pytorch_forecasting.data.examples import generate_ar_data
from pytorch_forecasting.metrics import SMAPE

# %%
pl.__version__
# Out:
# '1.4.9'

# %% [markdown]
# ## Load data
# We generate a synthetic dataset to demonstrate the network's capabilities. The data consists of a quadratic trend and a seasonality component.

# %%
data = generate_ar_data(seasonality=10.0, timesteps=400, n_series=100, seed=42)
data["static"] = 2
data["date"] = pd.Timestamp("2020-01-01") + pd.to_timedelta(data.time_idx, "D")
data.head()
# Out:
#    series  time_idx     value  static       date
# 0       0         0 -0.000000       2 2020-01-01
# 1       0         1 -0.046501       2 2020-01-02
# 2       0         2 -0.097796       2 2020-01-03
# 3       0         3 -0.144397       2 2020-01-04
# 4       0         4 -0.177954       2 2020-01-05

# %%
# create dataset and dataloaders
max_encoder_length = 60
max_prediction_length = 20

training_cutoff = data["time_idx"].max() - max_prediction_length

context_length = max_encoder_length
prediction_length = max_prediction_length

training = TimeSeriesDataSet(
    data[lambda x: x.time_idx <= training_cutoff],
    time_idx="time_idx",
    target="value",
    categorical_encoders={"series": NaNLabelEncoder().fit(data.series)},
    group_ids=["series"],
    # only unknown variable is "value" - and N-Beats can also not take any additional variables
    time_varying_unknown_reals=["value"],
    max_encoder_length=context_length,
    max_prediction_length=prediction_length,
)

validation = TimeSeriesDataSet.from_dataset(
    training, data, min_prediction_idx=training_cutoff + 1
)
batch_size = 128
train_dataloader = training.to_dataloader(
    train=True, batch_size=batch_size, num_workers=0
)
val_dataloader = validation.to_dataloader(
    train=False, batch_size=batch_size, num_workers=0
)

# %% [markdown]
# ## Calculate baseline error

# %%
# calculate baseline absolute error
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
baseline_predictions = Baseline().predict(val_dataloader)
SMAPE()(baseline_predictions, actuals)
# Out:
# tensor(0.5462)

# %% [markdown]
# ## Train network

# %%
pl.seed_everything(42)
trainer = pl.Trainer(gpus=0, gradient_clip_val=0.01)
net = NBeats.from_dataset(
    training,
    learning_rate=3e-2,
    weight_decay=1e-2,
    widths=[32, 512],
    backcast_loss_ratio=0.1,
)
# Out:
# Global seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
# find optimal learning rate
res = trainer.tuner.lr_find(
    net, train_dataloader=train_dataloader, val_dataloaders=val_dataloader, min_lr=1e-5
)
print(f"suggested learning rate: {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
net.hparams.learning_rate = res.suggestion()
# Out:
# /tmp/Python/python-3.9.6/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:817: LightningDeprecationWarning: `trainer.tune(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.tune(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
#
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | loss            | MASE       | 0
# 1 | logging_metrics | ModuleList | 0
# 2 | net_blocks      | ModuleList | 1.7 M
# -----------------------------------------------
# 1.7 M     Trainable params
# 0         Non-trainable params
# 1.7 M     Total params
# 6.851     Total estimated model params size (MB)
# Global seed set to 42
# Finding best initial lr: 100%|██████████| 100/100 [01:11<00:00,  1.17s/it]Restoring states from the checkpoint file at /work/notebooks/PyTorch-Forecasting/lr_find_temp_model.ckpt
# Restored all states from the checkpoint file at /work/notebooks/PyTorch-Forecasting/lr_find_temp_model.ckpt
# Finding best initial lr: 100%|██████████| 100/100 [01:14<00:00,  1.34it/s]
# suggested learning rate: 0.004466835921509632

# %%
early_stop_callback = EarlyStopping(
    monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min"
)
trainer = pl.Trainer(
    max_epochs=100,
    gpus=0,
    weights_summary="top",
    gradient_clip_val=0.01,
    callbacks=[early_stop_callback],
    limit_train_batches=30,
)


net = NBeats.from_dataset(
    training,
    learning_rate=4e-3,
    log_interval=10,
    log_val_interval=1,
    weight_decay=1e-2,
    widths=[32, 512],
    backcast_loss_ratio=1.0,
)

trainer.fit(
    net,
    train_dataloader=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /tmp/Python/python-3.9.6/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:530: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
#
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | loss            | MASE       | 0
# 1 | logging_metrics | ModuleList | 0
# 2 | net_blocks      | ModuleList | 1.7 M
# -----------------------------------------------
# 1.7 M     Trainable params
# 0         Non-trainable params
# 1.7 M     Total params
# 6.851     Total estimated model params size (MB)
# Global seed set to 42
# Epoch 0:  97%|█████████▋| 30/31 [00:20<00:00,  1.49it/s, loss=3.78, v_num=0, train_loss_step=2.330]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 31/31 [00:21<00:00,  1.46it/s, loss=3.78, v_num=0, train_loss_step=2.330, val_loss=2.030]
# Epoch 1:  97%|█████████▋| 30/31 [00:17<00:00,  1.81it/s, loss=2.06, v_num=0, train_loss_step=1.110, val_loss=2.030, train_loss_epoch=4.250]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 31/31 [00:18<00:00,  1.76it/s, loss=2.06, v_num=0, train_loss_step=1.110, val_loss=0.852, train_loss_epoch=4.250]
# Epoch 2:  97%|█████████▋| 30/31 [00:16<00:00,  1.94it/s, loss=1.46, v_num=0, train_loss_step=0.959, val_loss=0.852, train_loss_epoch=1.630]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 31/31 [00:17<00:00,  1.87it/s, loss=1.46, v_num=0, train_loss_step=0.959, val_loss=0.803, train_loss_epoch=1.630]
# Epoch 3:  97%|█████████▋| 30/31 [00:15<00:00,  1.97it/s, loss=1.33, v_num=0, train_loss_step=0.950, val_loss=0.803, train_loss_epoch=0.966]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|██████████| 31/31 [00:16<00:00,  1.90it/s, loss=1.33, v_num=0, train_loss_step=0.950, val_loss=0.776, train_loss_epoch=0.966]
# Epoch 4:  97%|█████████▋| 30/31 [00:32<00:01,  1.06s/it, loss=1.24, v_num=0, train_loss_step=0.884, val_loss=0.776, train_loss_epoch=0.904]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|██████████| 31/31 [00:34<00:00,  1.07s/it, loss=1.24, v_num=0, train_loss_step=0.884, val_loss=0.793, train_loss_epoch=0.904]
# Epoch 5:  97%|█████████▋| 30/31 [00:17<00:00,  1.76it/s, loss=1.17, v_num=0, train_loss_step=0.880, val_loss=0.793, train_loss_epoch=0.874]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 31/31 [00:19<00:00,  1.66it/s, loss=1.17, v_num=0, train_loss_step=0.880, val_loss=0.783, train_loss_epoch=0.874]
# Epoch 6:  97%|█████████▋| 30/31 [00:23<00:00,  1.31it/s, loss=1.14, v_num=0, train_loss_step=0.906, val_loss=0.783, train_loss_epoch=0.869]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 31/31 [00:24<00:00,  1.29it/s, loss=1.14, v_num=0, train_loss_step=0.906, val_loss=0.800, train_loss_epoch=0.869]
# Epoch 7:  97%|█████████▋| 30/31 [00:26<00:00,  1.18it/s, loss=1.1, v_num=0, train_loss_step=0.875, val_loss=0.800, train_loss_epoch=0.879]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|██████████| 31/31 [00:28<00:00,  1.14it/s, loss=1.1, v_num=0, train_loss_step=0.875, val_loss=0.803, train_loss_epoch=0.879]
# Epoch 8:  97%|█████████▋| 30/31 [00:36<00:01,  1.17s/it, loss=1.08, v_num=0, train_loss_step=0.863, val_loss=0.803, train_loss_epoch=0.867]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|██████████| 31/31 [00:37<00:00,  1.19s/it, loss=1.08, v_num=0, train_loss_step=0.863, val_loss=0.796, train_loss_epoch=0.867]
# Epoch 9:  97%|█████████▋| 30/31 [00:27<00:00,  1.14it/s, loss=1.07, v_num=0, train_loss_step=0.909, val_loss=0.796, train_loss_epoch=0.857]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|██████████| 31/31 [00:29<00:00,  1.09it/s, loss=1.07, v_num=0, train_loss_step=0.909, val_loss=0.794, train_loss_epoch=0.857]
# Epoch 10:  97%|█████████▋| 30/31 [00:24<00:00,  1.28it/s, loss=1.05, v_num=0, train_loss_step=0.822, val_loss=0.794, train_loss_epoch=0.850]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|██████████| 31/31 [00:26<00:00,  1.21it/s, loss=1.05, v_num=0, train_loss_step=0.822, val_loss=0.789, train_loss_epoch=0.850]
# Epoch 11:  97%|█████████▋| 30/31 [00:20<00:00,  1.50it/s, loss=1.04, v_num=0, train_loss_step=0.794, val_loss=0.789, train_loss_epoch=0.835]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|██████████| 31/31 [00:21<00:00,  1.50it/s, loss=1.04, v_num=0, train_loss_step=0.794, val_loss=0.782, train_loss_epoch=0.835]
# Epoch 12:  97%|█████████▋| 30/31 [00:12<00:00,  2.39it/s, loss=1.02, v_num=0, train_loss_step=0.801, val_loss=0.782, train_loss_epoch=0.816]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|██████████| 31/31 [00:15<00:00,  2.02it/s, loss=1.02, v_num=0, train_loss_step=0.801, val_loss=0.780, train_loss_epoch=0.816]
# Epoch 13:  97%|█████████▋| 30/31 [00:22<00:00,  1.35it/s, loss=1.02, v_num=0, train_loss_step=0.808, val_loss=0.780, train_loss_epoch=0.814]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|██████████| 31/31 [00:24<00:00,  1.30it/s, loss=1.02, v_num=0, train_loss_step=0.808, val_loss=0.786, train_loss_epoch=0.814]
# Epoch 13: 100%|██████████| 31/31 [00:27<00:00,  1.17it/s, loss=1.02, v_num=0, train_loss_step=0.808, val_loss=0.786, train_loss_epoch=0.814]

# %% [markdown]
# ## Evaluate Results

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_model = NBeats.load_from_checkpoint(best_model_path)

# %%
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = best_model.predict(val_dataloader)
(actuals - predictions).abs().mean()
# Out:
# tensor(0.1866)

# %% [markdown]
# Looking at random samples from the validation set is always a good way to understand if the forecast is reasonable - and it is!

# %%
raw_predictions, x = best_model.predict(val_dataloader, mode="raw", return_x=True)

# %%
for idx in range(10):  # plot 10 examples
    best_model.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True)

# %% [markdown]
# ## Interpret model

# %%
for idx in range(10):  # plot 10 examples
    best_model.plot_interpretation(x, raw_predictions, idx=idx)
